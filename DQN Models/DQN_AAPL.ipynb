# %%
#IMPORT LIBRARIES
import gymnasium as gym
from gym_anytrading.envs import TradingEnv, StocksEnv, Actions, Positions
from finta import TA

from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import DQN

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

# %%
df = pd.read_csv(r'C:\Users\abhis\OneDrive\Desktop\FinRL\data\AAPL.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2019-02-28  43.580002  43.727501  43.230000  43.287498  41.672825
# 1  2019-03-01  43.570000  43.787498  43.222500  43.742500  42.110855
# 2  2019-03-04  43.922501  44.437500  43.492500  43.962502  42.322651
# 3  2019-03-05  43.985001  44.000000  43.634998  43.882500  42.245636
# 4  2019-03-06  43.667500  43.872501  43.485001  43.630001  42.002560
#
#       Volume
# 0  112861600
# 1  103544800
# 2  109744800
# 3   78949600
# 4   83241600

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
df.sort_values('Date', ascending=True, inplace=True)
df.set_index("Date", inplace=True)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-02-28  43.580002  43.727501  43.230000  43.287498  41.672825  112861600
# 2019-03-01  43.570000  43.787498  43.222500  43.742500  42.110855  103544800
# 2019-03-04  43.922501  44.437500  43.492500  43.962502  42.322651  109744800
# 2019-03-05  43.985001  44.000000  43.634998  43.882500  42.245636   78949600
# 2019-03-06  43.667500  43.872501  43.485001  43.630001  42.002560   83241600

# %%
env = gym.make('stocks-v0', df=df, frame_bound=(20, 1000), window_size=20)
# Out:
# c:\Users\abhis\Anaconda3\envs\env\lib\site-packages\gymnasium\utils\passive_env_checker.py:42: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (20, 2)
#   logger.warn(

# %%
observation = env.reset()
while True:
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    # env.render()
    if done:
        print("info:", info)
        break
plt.figure(figsize=(30, 15))
plt.cla()
env.unwrapped.render_all()
plt.show()
# Out:
# info: {'total_reward': 108.78485870361328, 'total_profit': 0.08121937514201717, 'position': <Positions.Short: 0>}

# %%
df['Volume'] = df['Volume'].astype(float)
df['SMA'] = TA.SMA(df, 20)
df['RSI'] = TA.RSI(df)
df['OBV'] = TA.OBV(df)

df.fillna(0, inplace=True)

def add_signals(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'Close'].to_numpy()[start:end]
    signal_features = env.df.loc[:, ['Close', 'Volume', 'SMA', 'RSI', 'OBV']].to_numpy()[start:end]
    return prices, signal_features

# %%
class CustomTradingEnv(StocksEnv):
    _process_data = add_signals

#CREATE UPDATED STOCK ENV
env2 = CustomTradingEnv(df=df, window_size=12, frame_bound=(20, 1000))
env_maker = lambda: env2
env = DummyVecEnv([env_maker])

# %%
model = DQN("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=500_000)
# Out:
# Using cuda device
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 16471    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3916     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 16842    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7832     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.777    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 16859    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11748    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.702    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 16840    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 15664    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.628    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 16785    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19580    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.554    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 16547    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 23496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.479    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 16587    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 27412    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.405    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 16787    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 31328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 16773    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 35244    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.256    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 16704    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 39160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.182    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 16749    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 43076    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.107    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 16587    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 46992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 11881    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 50908    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.39e+06 |
# |    n_updates        | 226      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 5745     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 54824    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.49e+06 |
# |    n_updates        | 1205     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 4001     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 58740    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.99e+06 |
# |    n_updates        | 2184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 3180     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 62656    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.88e+06 |
# |    n_updates        | 3163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2676     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 66572    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.78e+06 |
# |    n_updates        | 4142     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2339     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 70488    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.49e+06 |
# |    n_updates        | 5121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2115     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 74404    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14e+06 |
# |    n_updates        | 6100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1943     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 78320    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.68e+05 |
# |    n_updates        | 7079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1809     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 82236    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.67e+05 |
# |    n_updates        | 8058     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1703     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 86152    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.57e+05 |
# |    n_updates        | 9037     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1619     |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 90068    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.47e+06 |
# |    n_updates        | 10016    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1545     |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 93984    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.35e+06 |
# |    n_updates        | 10995    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1485     |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 97900    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.23e+05 |
# |    n_updates        | 11974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1432     |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 101816   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.14
|
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.48e+05 |
# |    n_updates        | 57987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 905      |
# |    time_elapsed     | 315      |
# |    total_timesteps  | 285868   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.73e+05 |
# |    n_updates        | 58966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 904      |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 289784   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.98e+05 |
# |    n_updates        | 59945    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 902      |
# |    time_elapsed     | 325      |
# |    total_timesteps  | 293700   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.84e+05 |
# |    n_updates        | 60924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 900      |
# |    time_elapsed     | 330      |
# |    total_timesteps  | 297616   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.94e+05 |
# |    n_updates        | 61903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 899      |
# |    time_elapsed     | 335      |
# |    total_timesteps  | 301532   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.12e+05 |
# |    n_updates        | 62882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 897      |
# |    time_elapsed     | 340      |
# |    total_timesteps  | 305448   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.6e+05  |
# |    n_updates        | 63861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 895      |
# |    time_elapsed     | 345      |
# |    total_timesteps  | 309364   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.59e+05 |
# |    n_updates        | 64840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 894      |
# |    time_elapsed     | 350      |
# |    total_timesteps  | 313280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.31e+05 |
# |    n_updates        | 65819    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 892      |
# |    time_elapsed     | 355      |
# |    total_timesteps  | 317196   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.28e+05 |
# |    n_updates        | 66798    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 891      |
# |    time_elapsed     | 360      |
# |    total_timesteps  | 321112   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.46e+05 |
# |    n_updates        | 67777    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 890      |
# |    time_elapsed     | 365      |
# |    total_timesteps  | 325028   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.89e+05 |
# |    n_updates        | 68756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 888      |
# |    time_elapsed     | 370      |
# |    total_timesteps  | 328944   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.33e+05 |
# |    n_updates        | 69735    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 888      |
# |    time_elapsed     | 374      |
# |    total_timesteps  | 332860   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.36e+05 |
# |    n_updates        | 70714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 886      |
# |    time_elapsed     | 379      |
# |    total_timesteps  | 336776   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.13e+05 |
# |    n_updates        | 71693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 885      |
# |    time_elapsed     | 384      |
# |    total_timesteps  | 340692   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.44e+05 |
# |    n_updates        | 72672    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 884      |
# |    time_elapsed     | 389      |
# |    total_timesteps  | 344608   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.88e+05 |
# |    n_updates        | 73651    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 883      |
# |    time_elapsed     | 394      |
# |    total_timesteps  | 348524   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.05e+05 |
# |    n_updates        | 74630    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 882      |
# |    time_elapsed     | 399      |
# |    total_timesteps  | 352440   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.09e+05 |
# |    n_updates        | 75609    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 881      |
# |    time_elapsed     | 404      |
# |    total_timesteps  | 356356   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.49e+05 |
# |    n_updates        | 76588    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 880      |
# |    time_elapsed     | 409      |
# |    total_timesteps  | 360272   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.79e+05 |
# |    n_updates        | 77567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 879      |
# |    time_elapsed     | 414      |
# |    total_timesteps  | 364188   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.46e+05 |
# |    n_updates        | 78546    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 878      |
# |    time_elapsed     | 418      |
# |    total_timesteps  | 368104   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.73e+05 |
# |    n_updates        | 79525    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 880      |
# |    time_elapsed     | 422      |
# |    total_timesteps  | 372020   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.56e+05 |
# |    n_updates        | 80504    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 881      |
# |    time_elapsed     | 426      |
# |    total_timesteps  | 375936   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.09e+05 |
# |    n_updates        | 81483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 882      |
# |    time_elapsed     | 430      |
# |    total_timesteps  | 379852   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.58e+05 |
# |    n_updates        | 82462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 884      |
# |    time_elapsed     | 434      |
# |    total_timesteps  | 383768   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.42e+05 |
# |    n_updates        | 83441    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 885      |
# |    time_elapsed     | 438      |
# |    total_timesteps  | 387684   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.77e+05 |
# |    n_updates        | 84420    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 886      |
# |    time_elapsed     | 441      |
# |    total_timesteps  | 391600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.64e+05 |
# |    n_updates        | 85399    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 887      |
# |    time_elapsed     | 445      |
# |    total_timesteps  | 395516   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.98e+05 |
# |    n_updates        | 86378    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 888      |
# |    time_elapsed     | 449      |
# |    total_timesteps  | 399432   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.42e+05 |
# |    n_updates        | 87357    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 889      |
# |    time_elapsed     | 453      |
# |    total_timesteps  | 403348   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.71e+05 |
# |    n_updates        | 88336    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 890      |
# |    time_elapsed     | 457      |
# |    total_timesteps  | 407264   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.37e+05 |
# |    n_updates        | 89315    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 891      |
# |    time_elapsed     | 461      |
# |    total_timesteps  | 411180   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.68e+05 |
# |    n_updates        | 90294    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 893      |
# |    time_elapsed     | 464      |
# |    total_timesteps  | 415096   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.59e+05 |
# |    n_updates        | 91273    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 894      |
# |    time_elapsed     | 468      |
# |    total_timesteps  | 419012   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.92e+05 |
# |    n_updates        | 92252    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 895      |
# |    time_elapsed     | 472      |
# |    total_timesteps  | 422928   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6e+05    |
# |    n_updates        | 93231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 896      |
# |    time_elapsed     | 476      |
# |    total_timesteps  | 426844   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.58e+05 |
# |    n_updates        | 94210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 897      |
# |    time_elapsed     | 480      |
# |    total_timesteps  | 430760   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.08e+05 |
# |    n_updates        | 95189    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 898      |
# |    time_elapsed     | 483      |
# |    total_timesteps  | 434676   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.92e+05 |
# |    n_updates        | 96168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 899      |
# |    time_elapsed     | 487      |
# |    total_timesteps  | 438592   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.45e+05 |
# |    n_updates        | 97147    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 900      |
# |    time_elapsed     | 491      |
# |    total_timesteps  | 442508   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.88e+05 |
# |    n_updates        | 98126    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 901      |
# |    time_elapsed     | 495      |
# |    total_timesteps  | 446424   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.26e+05 |
# |    n_updates        | 99105    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 902      |
# |    time_elapsed     | 499      |
# |    total_timesteps  | 450340   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.07e+05 |
# |    n_updates        | 100084   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 903      |
# |    time_elapsed     | 502      |
# |    total_timesteps  | 454256   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.34e+05 |
# |    n_updates        | 101063   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 904      |
# |    time_elapsed     | 506      |
# |    total_timesteps  | 458172   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.12e+05 |
# |    n_updates        | 102042   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 905      |
# |    time_elapsed     | 510      |
# |    total_timesteps  | 462088   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.06e+05 |
# |    n_updates        | 103021   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 905      |
# |    time_elapsed     | 514      |
# |    total_timesteps  | 466004   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.9e+05  |
# |    n_updates        | 104000   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 905      |
# |    time_elapsed     | 518      |
# |    total_timesteps  | 469920   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.06e+05 |
# |    n_updates        | 104979   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 905      |
# |    time_elapsed     | 523      |
# |    total_timesteps  | 473836   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.01e+05 |
# |    n_updates        | 105958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 905      |
# |    time_elapsed     | 527      |
# |    total_timesteps  | 477752   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.24e+05 |
# |    n_updates        | 106937   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 905      |
# |    time_elapsed     | 531      |
# |    total_timesteps  | 481668   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.3e+05  |
# |    n_updates        | 107916   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 905      |
# |    time_elapsed     | 536      |
# |    total_timesteps  | 485584   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.42e+05 |
# |    n_updates        | 108895   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 905      |
# |    time_elapsed     | 540      |
# |    total_timesteps  | 489500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.64e+05 |
# |    n_updates        | 109874   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 905      |
# |    time_elapsed     | 545      |
# |    total_timesteps  | 493416   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.09e+05 |
# |    n_updates        | 110853   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 903      |
# |    time_elapsed     | 550      |
# |    total_timesteps  | 497332   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.01e+05 |
# |    n_updates        | 111832   |
# ----------------------------------

# %%
env = CustomTradingEnv(df=df, window_size=12, frame_bound=(1000, 1250))
obs, _ = env.reset()

while True:
    action, _states = model.predict(obs)
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    # env.render()
    if done:
        print("info:", info)
        break
# Out:
# info: {'total_reward': 33.37998999999999, 'total_profit': 1.1511040542610729, 'position': <Positions.Long: 1>}

# %%
plt.figure(figsize=(20, 9))
plt.cla()
env.render_all()
plt.show()
