# %%
#IMPORT LIBRARIES
import gymnasium as gym
from gym_anytrading.envs import TradingEnv, StocksEnv, Actions, Positions
from finta import TA

from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import PPO 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

# %%
df = pd.read_csv(r'C:\Users\abhis\OneDrive\Desktop\FinRL\data\AAPL.csv')
df.head()
df.shape
# Out:
# (1258, 7)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
df.sort_values('Date', ascending=True, inplace=True)
df.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2019-02-28  43.580002  43.727501  43.230000  43.287498  41.672825  112861600
# 1 2019-03-01  43.570000  43.787498  43.222500  43.742500  42.110855  103544800
# 2 2019-03-04  43.922501  44.437500  43.492500  43.962502  42.322651  109744800
# 3 2019-03-05  43.985001  44.000000  43.634998  43.882500  42.245636   78949600
# 4 2019-03-06  43.667500  43.872501  43.485001  43.630001  42.002560   83241600

# %%
df.set_index("Date", inplace=True)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-02-28  43.580002  43.727501  43.230000  43.287498  41.672825  112861600
# 2019-03-01  43.570000  43.787498  43.222500  43.742500  42.110855  103544800
# 2019-03-04  43.922501  44.437500  43.492500  43.962502  42.322651  109744800
# 2019-03-05  43.985001  44.000000  43.634998  43.882500  42.245636   78949600
# 2019-03-06  43.667500  43.872501  43.485001  43.630001  42.002560   83241600

# %%
env = gym.make('stocks-v0', df=df, frame_bound=(20, 1000), window_size=20)
# Out:
# c:\Users\abhis\Anaconda3\envs\env\lib\site-packages\gymnasium\utils\passive_env_checker.py:42: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (20, 2)
#   logger.warn(

# %%
observation = env.reset()
while True:
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    # env.render()
    if done:
        print("info:", info)
        break
plt.figure(figsize=(25, 16))
plt.cla()
env.unwrapped.render_all()
plt.show()
# Out:
# info: {'total_reward': 108.78485870361328, 'total_profit': 0.08121937514201717, 'position': <Positions.Short: 0>}

# %%
df['Volume'] = df['Volume'].astype(float)
df['SMA'] = TA.SMA(df, 20)
df['RSI'] = TA.RSI(df)
df['OBV'] = TA.OBV(df)

df.fillna(0, inplace=True)

def add_signals(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'Close'].to_numpy()[start:end]
    signal_features = env.df.loc[:, ['Close', 'Volume', 'SMA', 'RSI', 'OBV']].to_numpy()[start:end]
    return prices, signal_features

# %%
class CustomTradingEnv(StocksEnv):
    _process_data = add_signals

#CREATE UPDATED STOCK ENV
env2 = CustomTradingEnv(df=df, window_size=20, frame_bound=(20, 1000))
env_maker = lambda: env2
env = DummyVecEnv([env_maker])

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=500_000)
# Out:
# Using cuda device
# -----------------------------
# | time/              |      |
# |    fps             | 733  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015517807 |
# |    clip_fraction        | 0.055       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | 0.0187      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.5        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00432    |
# |    value_loss           | 17.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 538          |
# |    iterations           | 3            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0038943868 |
# |    clip_fraction        | 0.00337      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.678       |
# |    explained_variance   | 0.0835       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12           |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 20.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 525         |
# |    iterations           | 4           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009323859 |
# |    clip_fraction        | 0.0185      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.635      |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00146    |
# |    value_loss           | 34.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 5            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0009436085 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.639       |
# |    explained_variance   | 0.279        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.31         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 23.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 511          |
# |    iterations           | 6            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0023235318 |
# |    clip_fraction        | 0.00156      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.624       |
# |    explained_variance   | 0.213        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23           |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000455    |
# |    value_loss           | 35.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 506         |
# |    iterations           | 7           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.003105518 |
# |    clip_fraction        | 0.00937     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.321       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.87        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 28.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 496          |
# |    iterations           | 8            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0054832157 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.585       |
# |    explained_variance   | 0.278        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.3         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000988    |
# |    value_loss           | 25.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 493          |
# |    iterations           | 9            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0028358742 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.618       |
# |    explained_variance   | 0.247        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.8         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 35.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 488          |
# |    iterations           | 10           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0074245124 |
# |    clip_fraction        | 0.0472       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.577       |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.7         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00447     |
# |    value_loss           | 28.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 11           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0009894336 |
# |    clip_fraction        | 0.00967      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.54        |
# |    explained_variance   | 0.326        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.53         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 31.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 488         |
# |    iterations           | 12          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.002788193 |
# |    clip_fraction        | 0.0202      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.325       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.5        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 32.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 489          |
# |    iterations           | 13           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0014656007 |
# |    clip_fraction        | 0.004        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.573       |
# |    explained_variance   | 0.287        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.9         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000606    |
# |    value_loss           | 28.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 488          |
# |    iterations           | 14           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0035824915 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.592       |
# |    explained_variance   | 0.228        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.5         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 30.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 485         |
# |    iterations           | 15          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.004278761 |
# |    clip_fraction        | 0.0193      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.572      |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18          |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000932   |
# |    value_loss           | 34.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 486          |
# |    iterations           | 16           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0013060751 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.583       |
# |    explained_variance   | 0.314        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.4         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00291     |
# |    value_loss           | 30.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 17          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.002434696 |
# |    clip_fraction        | 0.0243      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.8        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000995   |
# |    value_loss           | 29.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 18           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0034689764 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.606       |
# |    explained_variance   | 0.283        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.4         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00432     |
# |    value_loss           | 32.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 488         |
# |    iterations           | 19          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.003481823 |
# |    clip_fraction        | 0.00884     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.594      |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.5        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000864   |
# |    value_loss           | 31.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 486        |
# |    iterations           | 20         |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00475081 |
# |    clip_fraction        | 0.0202     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.582     |
# |    explained_variance   | 0.305      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14         |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.00057   |
# |    value_loss           | 31.4       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 21           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0016693202 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.538       |
# |    explained_variance   | 0.373        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13           |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000676    |
# |    value_loss           | 33.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 485          |
# |    iterations           | 22           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0024323831 |
# |    clip_fraction        | 0.00937      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.521       |
# |    explained_variance   | 0.434        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.2         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000786    |
# |    value_loss           | 33.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 23          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004400181 |
# |    clip_fraction        | 0.0254      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.502      |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.2        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00286    |
# |    value_loss           | 33.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 485          |
# |    iterations           | 24           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0025334875 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.522       |
# |    explained_variance   | 0.408        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.7         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00277     |
# |    value_loss           | 38.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 486          |
# |    iterations           | 25           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0030684238 |
# |    clip_fraction        | 0.0454       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | 0.453        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.5         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00408     |
# |    value_loss           | 33.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 26          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005409398 |
# |    clip_fraction        | 0.0422      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.532      |
# |    explained_variance   | 0.528       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00368    |
# |    value_loss           | 27.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 486          |
# |    iterations           | 27           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0031239002 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.5         |
# |    explained_variance   | 0.47         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.4         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 29           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 28          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.000727345 |
# |    clip_fraction        | 0.0114      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.484      |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000317   |
# |    value_loss           | 29.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 486          |
# |    iterations           | 29           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0038977247 |
# |    clip_fraction        | 0.0367       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.456       |
# |    explained_variance   | 0.425        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.4         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 36           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 484          |
# |    iterations           | 30           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0018358709 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.474       |
# |    explained_variance   | 0.488        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.3         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 31.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 484          |
# |    iterations           | 31           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0020189187 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.481       |
# |    explained_variance   | 0.478        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.8         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 33.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 484          |
# |    iterations           | 32           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0034946038 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.452       |
# |    explained_variance   | 0.482        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.5         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 36.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 483          |
# |    iterations           | 33           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0058029275 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.45        |
# |    explained_variance   | 0.456        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.1         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00197     |
# |    value_loss           | 41.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 34          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004244133 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.42       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.6        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00365    |
# |    value_loss           | 30.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 481          |
# |    iterations           | 35           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0028179202 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.402       |
# |    explained_variance   | 0.489        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.2         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00491     |
# |    value_loss           | 32.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 481          |
# |    iterations           | 36           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0025447896 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.411       |
# |    explained_variance   | 0.471        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.3         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 31.2         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 480        |
# |    iterations           | 37         |
# |    time_elapsed         | 157        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00259437 |
# |    clip_fraction        | 0.033      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.424     |
# |    explained_variance   | 0.504      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 23.4       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.00338   |
# |    value_loss           | 39.5       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 478          |
# |    iterations           | 38           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0021893813 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.445       |
# |    explained_variance   | 0.493        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.8         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 30.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 39          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004104971 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.418      |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.9        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00099    |
# |    value_loss           | 27          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 40          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.003415796 |
# |    clip_fraction        | 0.0339      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.396      |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.2        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00263    |
# |    value_loss           | 29          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 41          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.005742654 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.376      |
# |    explained_variance   | 0.508       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.9        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00221    |
# |    value_loss           | 32.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 475          |
# |    iterations           | 42           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0028564194 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.327       |
# |    explained_variance   | 0.551        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.7         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00246     |
# |    value_loss           | 30.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 475          |
# |    iterations           | 43           |
# |    time_elapsed         | 185          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0025829205 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.322       |
# |    explained_variance   | 0.519        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.1         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00216     |
# |    value_loss           | 35.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 475          |
# |    iterations           | 44           |
# |    time_elapsed         | 189          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0023446353 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.304       |
# |    explained_variance   | 0.572        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15           |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00233     |
# |    value_loss           | 30.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 474          |
# |    iterations           | 45           |
# |    time_elapsed         | 194          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0017908076 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.27        |
# |    explained_variance   | 0.514        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.9         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000427    |
# |    value_loss           | 32.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 46          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.002476271 |
# |    clip_fraction        | 0.021       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.282      |
# |    explained_variance   | 0.581       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.4        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00145    |
# |    value_loss           | 26.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 474          |
# |    iterations           | 47           |
# |    time_elapsed         | 202          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0022029383 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.267       |
# |    explained_variance   | 0.509        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.5         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000752    |
# |    value_loss           | 35.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 474          |
# |    iterations           | 48           |
# |    time_elapsed         | 207          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0028300858 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.253       |
# |    explained_variance   | 0.557        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.2         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -3.57e-05    |
# |    value_loss           | 30.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 49           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0023981673 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | 0.571        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.3         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00302     |
# |    value_loss           | 30.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 50           |
# |    time_elapsed         | 216          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0025871107 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.254       |
# |    explained_variance   | 0.553        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22           |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00226     |
# |    value_loss           | 30.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 51           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0028066495 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.251       |
# |    explained_variance   | 0.59         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.93         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 29.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 472          |
# |    iterations           | 52           |
# |    time_elapsed         | 225          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0035174794 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.245       |
# |    explained_variance   | 0.635        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.4         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 25.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 53           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0021537552 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.209       |
# |    explained_variance   | 0.595        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.3         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 28.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 54           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0015437619 |
# |    clip_fraction        | 0.0245       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.204       |
# |    explained_variance   | 0.57         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.8         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00265     |
# |    value_loss           | 32.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 473         |
# |    iterations           | 55          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.001654699 |
# |    clip_fraction        | 0.016       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.196      |
# |    explained_variance   | 0.609       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.3        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.000427    |
# |    value_loss           | 31.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 56           |
# |    time_elapsed         | 242          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0021838285 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.219       |
# |    explained_variance   | 0.656        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.9         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 28.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 57           |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0018122738 |
# |    clip_fraction        | 0.0149       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.213       |
# |    explained_variance   | 0.66         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.3         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 28.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 58           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0020001444 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.226       |
# |    explained_variance   | 0.644        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.5         |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.000967    |
# |    value_loss           | 27.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 472         |
# |    iterations           | 59          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.001624991 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.244      |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.2        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0017     |
# |    value_loss           | 24.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 60           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0011250109 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.22        |
# |    explained_variance   | 0.657        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.4         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.000452    |
# |    value_loss           | 25.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 61           |
# |    time_elapsed         | 264          |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0011666846 |
# |    clip_fraction        | 0.0183       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.226       |
# |    explained_variance   | 0.653        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.7         |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -8.77e-05    |
# |    value_loss           | 26.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 62           |
# |    time_elapsed         | 267          |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0040196846 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.231       |
# |    explained_variance   | 0.696        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.8         |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 20.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 63           |
# |    time_elapsed         | 272          |
# |    total_timesteps      | 129024       |
# | train/                  |              |
# |    approx_kl            | 0.0023609984 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.218       |
# |    explained_variance   | 0.66         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.1         |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.00244     |
# |    value_loss           | 27.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 474          |
# ...
# |    total_timesteps      | 460800      |
# | train/                  |             |
# |    approx_kl            | 0.003920426 |
# |    clip_fraction        | 0.0258      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0779     |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.88        |
# |    n_updates            | 2240        |
# |    policy_gradient_loss | -0.000395   |
# |    value_loss           | 25          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 226          |
# |    time_elapsed         | 1011         |
# |    total_timesteps      | 462848       |
# | train/                  |              |
# |    approx_kl            | 0.0014221161 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0843      |
# |    explained_variance   | 0.798        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.6         |
# |    n_updates            | 2250         |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 29.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 227          |
# |    time_elapsed         | 1015         |
# |    total_timesteps      | 464896       |
# | train/                  |              |
# |    approx_kl            | 0.0017952172 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0853      |
# |    explained_variance   | 0.806        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.1         |
# |    n_updates            | 2260         |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 28.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 228          |
# |    time_elapsed         | 1019         |
# |    total_timesteps      | 466944       |
# | train/                  |              |
# |    approx_kl            | 0.0028380523 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.084       |
# |    explained_variance   | 0.8          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20           |
# |    n_updates            | 2270         |
# |    policy_gradient_loss | -0.00333     |
# |    value_loss           | 29.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 457          |
# |    iterations           | 229          |
# |    time_elapsed         | 1024         |
# |    total_timesteps      | 468992       |
# | train/                  |              |
# |    approx_kl            | 0.0016669573 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0774      |
# |    explained_variance   | 0.816        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.1         |
# |    n_updates            | 2280         |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 27.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 230          |
# |    time_elapsed         | 1028         |
# |    total_timesteps      | 471040       |
# | train/                  |              |
# |    approx_kl            | 0.0014451605 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0818      |
# |    explained_variance   | 0.805        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.5         |
# |    n_updates            | 2290         |
# |    policy_gradient_loss | -0.000986    |
# |    value_loss           | 27.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 231          |
# |    time_elapsed         | 1032         |
# |    total_timesteps      | 473088       |
# | train/                  |              |
# |    approx_kl            | 0.0016340008 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0764      |
# |    explained_variance   | 0.814        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.7         |
# |    n_updates            | 2300         |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 26.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 232          |
# |    time_elapsed         | 1036         |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0026701782 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.077       |
# |    explained_variance   | 0.795        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.22         |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | -0.00275     |
# |    value_loss           | 29.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 233          |
# |    time_elapsed         | 1041         |
# |    total_timesteps      | 477184       |
# | train/                  |              |
# |    approx_kl            | 0.0018858425 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.082       |
# |    explained_variance   | 0.845        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.64         |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -0.00063     |
# |    value_loss           | 25.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 234         |
# |    time_elapsed         | 1045        |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.003395043 |
# |    clip_fraction        | 0.0294      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0791     |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.03        |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.00279    |
# |    value_loss           | 29.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 235         |
# |    time_elapsed         | 1049        |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.002162044 |
# |    clip_fraction        | 0.0198      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0776     |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.7        |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00203    |
# |    value_loss           | 26.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 236          |
# |    time_elapsed         | 1053         |
# |    total_timesteps      | 483328       |
# | train/                  |              |
# |    approx_kl            | 0.0051395935 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0816      |
# |    explained_variance   | 0.796        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.9         |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | -0.000645    |
# |    value_loss           | 27.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 237          |
# |    time_elapsed         | 1058         |
# |    total_timesteps      | 485376       |
# | train/                  |              |
# |    approx_kl            | 0.0011318563 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0842      |
# |    explained_variance   | 0.814        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.3         |
# |    n_updates            | 2360         |
# |    policy_gradient_loss | -0.000202    |
# |    value_loss           | 24.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 238          |
# |    time_elapsed         | 1062         |
# |    total_timesteps      | 487424       |
# | train/                  |              |
# |    approx_kl            | 0.0019398965 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0873      |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.69         |
# |    n_updates            | 2370         |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 29.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 239          |
# |    time_elapsed         | 1066         |
# |    total_timesteps      | 489472       |
# | train/                  |              |
# |    approx_kl            | 0.0021548748 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0928      |
# |    explained_variance   | 0.751        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.2         |
# |    n_updates            | 2380         |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 39           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 240          |
# |    time_elapsed         | 1071         |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0018069299 |
# |    clip_fraction        | 0.0215       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.101       |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26           |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.000611    |
# |    value_loss           | 37.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 241          |
# |    time_elapsed         | 1075         |
# |    total_timesteps      | 493568       |
# | train/                  |              |
# |    approx_kl            | 0.0018774979 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.103       |
# |    explained_variance   | 0.788        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.7         |
# |    n_updates            | 2400         |
# |    policy_gradient_loss | 0.000122     |
# |    value_loss           | 32.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 458          |
# |    iterations           | 242          |
# |    time_elapsed         | 1079         |
# |    total_timesteps      | 495616       |
# | train/                  |              |
# |    approx_kl            | 0.0010476566 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.103       |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.52         |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 29.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 243          |
# |    time_elapsed         | 1084         |
# |    total_timesteps      | 497664       |
# | train/                  |              |
# |    approx_kl            | 0.0024496997 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.103       |
# |    explained_variance   | 0.732        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.6         |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.00331     |
# |    value_loss           | 43.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 244         |
# |    time_elapsed         | 1088        |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.002645158 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.12       |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.4        |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.00175    |
# |    value_loss           | 31.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 459          |
# |    iterations           | 245          |
# |    time_elapsed         | 1092         |
# |    total_timesteps      | 501760       |
# | train/                  |              |
# |    approx_kl            | 0.0019814577 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.131       |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.96         |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 34.3         |
# ------------------------------------------

# %%
env = CustomTradingEnv(df=df, window_size=20, frame_bound=(1000, 1250))
obs, _ = env.reset()

while True:
    action, _states = model.predict(obs)
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    # env.render()
    if done:
        print("info:", info)
        break
# Out:
# info: {'total_reward': 36.92001299999998, 'total_profit': 1.1524207855133233, 'position': <Positions.Long: 1>}

# %%
plt.figure(figsize=(20, 9))
plt.cla()
env.render_all()
plt.show()
