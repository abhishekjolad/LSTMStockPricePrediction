# %%
#IMPORT LIBRARIES
import gymnasium as gym
from gym_anytrading.envs import TradingEnv, StocksEnv, Actions, Positions
from finta import TA

from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import PPO 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

# %%
df = pd.read_csv(r"C:\Users\abhis\OneDrive\Desktop\FinRL\data\META.csv")
df.head()
df.shape
# Out:
# (1258, 7)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
df.sort_values('Date', ascending=True, inplace=True)
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2019-02-28  162.369995  163.500000  160.860001  161.449997  161.278885
# 1 2019-03-01  162.600006  163.130005  161.690002  162.279999  162.108002
# 2 2019-03-04  163.899994  167.500000  163.830002  167.369995  167.192596
# 3 2019-03-05  167.369995  171.880005  166.550003  171.259995  171.078476
# 4 2019-03-06  172.899994  173.570007  171.270004  172.509995  172.327148
#
#      Volume
# 0  11114200
# 1  11097800
# 2  18894700
# 3  28187900
# 4  21531700

# %%
df.set_index("Date", inplace=True)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-02-28  162.369995  163.500000  160.860001  161.449997  161.278885
# 2019-03-01  162.600006  163.130005  161.690002  162.279999  162.108002
# 2019-03-04  163.899994  167.500000  163.830002  167.369995  167.192596
# 2019-03-05  167.369995  171.880005  166.550003  171.259995  171.078476
# 2019-03-06  172.899994  173.570007  171.270004  172.509995  172.327148
#
#               Volume
# Date
# 2019-02-28  11114200
# 2019-03-01  11097800
# 2019-03-04  18894700
# 2019-03-05  28187900
# 2019-03-06  21531700

# %%
env = gym.make('stocks-v0', df=df, frame_bound=(20, 1000), window_size=20)
# Out:
# c:\Users\abhis\Anaconda3\envs\env\lib\site-packages\gymnasium\utils\passive_env_checker.py:42: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (20, 2)
#   logger.warn(

# %%
observation = env.reset()
while True:
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    # env.render()
    if done:
        print("info:", info)
        break
plt.figure(figsize=(25, 16))
plt.cla()
env.unwrapped.render_all()
plt.show()
# Out:
# info: {'total_reward': 38.84999084472656, 'total_profit': 0.03924715843337872, 'position': <Positions.Short: 0>}

# %%
df['Volume'] = df['Volume'].astype(float)
df['SMA'] = TA.SMA(df, 20)
df['RSI'] = TA.RSI(df)
df['OBV'] = TA.OBV(df)

df.fillna(0, inplace=True)

def add_signals(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'Close'].to_numpy()[start:end]
    signal_features = env.df.loc[:, ['Close', 'Volume', 'SMA', 'RSI', 'OBV']].to_numpy()[start:end]
    return prices, signal_features

# %%
class CustomTradingEnv(StocksEnv):
    _process_data = add_signals

#CREATE UPDATED STOCK ENV
env2 = CustomTradingEnv(df=df, window_size=20, frame_bound=(20, 1000))
env_maker = lambda: env2
env = DummyVecEnv([env_maker])

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=250_000)
# Out:
# Using cuda device
# -----------------------------
# | time/              |      |
# |    fps             | 608  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008307721 |
# |    clip_fraction        | 0.00664     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.688      |
# |    explained_variance   | 0.0013      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00163    |
# |    value_loss           | 179         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 3            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0027639065 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.688       |
# |    explained_variance   | 0.00924      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72.7         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 125          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 472          |
# |    iterations           | 4            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0090236105 |
# |    clip_fraction        | 0.00527      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.68        |
# |    explained_variance   | 0.0284       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 92.3         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 181          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 465         |
# |    iterations           | 5           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006367303 |
# |    clip_fraction        | 0.0265      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.0946      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.4        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00344    |
# |    value_loss           | 120         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 459        |
# |    iterations           | 6          |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00779754 |
# |    clip_fraction        | 0.036      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.642     |
# |    explained_variance   | 0.135      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 74.1       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00542   |
# |    value_loss           | 190        |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 460          |
# |    iterations           | 7            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0027126342 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.641       |
# |    explained_variance   | 0.193        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.3         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00233     |
# |    value_loss           | 145          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 454        |
# |    iterations           | 8          |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00571471 |
# |    clip_fraction        | 0.0141     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.619     |
# |    explained_variance   | 0.283      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 51.5       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00204   |
# |    value_loss           | 90.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 433         |
# |    iterations           | 9           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007798372 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.623      |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00443    |
# |    value_loss           | 109         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 10          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005132095 |
# |    clip_fraction        | 0.0317      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53          |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00326    |
# |    value_loss           | 96.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 11           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0031839318 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.634       |
# |    explained_variance   | 0.137        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 109          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 152          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 399          |
# |    iterations           | 12           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0036874774 |
# |    clip_fraction        | 0.0487       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.629       |
# |    explained_variance   | 0.267        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.6         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00412     |
# |    value_loss           | 91.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 13          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.004201115 |
# |    clip_fraction        | 0.0276      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.632      |
# |    explained_variance   | 0.18        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.1        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00333    |
# |    value_loss           | 125         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 392        |
# |    iterations           | 14         |
# |    time_elapsed         | 73         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01025416 |
# |    clip_fraction        | 0.0336     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.617     |
# |    explained_variance   | 0.191      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 63.2       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00325   |
# |    value_loss           | 110        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 386         |
# |    iterations           | 15          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007423747 |
# |    clip_fraction        | 0.0204      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.164       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.9        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00291    |
# |    value_loss           | 136         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 380         |
# |    iterations           | 16          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.002006887 |
# |    clip_fraction        | 0.0128      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.586      |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62          |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000898   |
# |    value_loss           | 165         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 377         |
# |    iterations           | 17          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005047526 |
# |    clip_fraction        | 0.0287      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | 0.155       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 153         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00378    |
# |    value_loss           | 271         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 373          |
# |    iterations           | 18           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0037383686 |
# |    clip_fraction        | 0.0257       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.609       |
# |    explained_variance   | 0.18         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 76.1         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00215     |
# |    value_loss           | 227          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 19          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004162874 |
# |    clip_fraction        | 0.00513     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75.1        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000513   |
# |    value_loss           | 172         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 369          |
# |    iterations           | 20           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0034252543 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.616       |
# |    explained_variance   | 0.259        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 146          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00226     |
# |    value_loss           | 269          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 367          |
# |    iterations           | 21           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0053455443 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.631       |
# |    explained_variance   | 0.334        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 171          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00461     |
# |    value_loss           | 222          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 363          |
# |    iterations           | 22           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0049930364 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.633       |
# |    explained_variance   | 0.377        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.1         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00369     |
# |    value_loss           | 120          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 23           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0043997485 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.625       |
# |    explained_variance   | 0.325        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.4         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.003       |
# |    value_loss           | 191          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 24          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009156446 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.624      |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.2        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00501    |
# |    value_loss           | 195         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 357         |
# |    iterations           | 25          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006626874 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.597      |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 130         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 175         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 356         |
# |    iterations           | 26          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.002555308 |
# |    clip_fraction        | 0.0311      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.318       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 101         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00181    |
# |    value_loss           | 207         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 355          |
# |    iterations           | 27           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0064022345 |
# |    clip_fraction        | 0.0752       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.611       |
# |    explained_variance   | 0.328        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 98.5         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00649     |
# |    value_loss           | 152          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 353          |
# |    iterations           | 28           |
# |    time_elapsed         | 162          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0053074686 |
# |    clip_fraction        | 0.0446       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.614       |
# |    explained_variance   | 0.311        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 71.6         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0027      |
# |    value_loss           | 162          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 352          |
# |    iterations           | 29           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0040439134 |
# |    clip_fraction        | 0.0713       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.6         |
# |    explained_variance   | 0.316        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.8         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00611     |
# |    value_loss           | 157          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 351          |
# |    iterations           | 30           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0059610493 |
# |    clip_fraction        | 0.0489       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.604       |
# |    explained_variance   | 0.367        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.4         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00365     |
# |    value_loss           | 129          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 31          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.003975806 |
# |    clip_fraction        | 0.0258      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.329       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 86.8        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0027     |
# |    value_loss           | 208         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 351          |
# |    iterations           | 32           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0036388761 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.588       |
# |    explained_variance   | 0.426        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 83.9         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 143          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 350         |
# |    iterations           | 33          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.004365136 |
# |    clip_fraction        | 0.0531      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.573      |
# |    explained_variance   | 0.455       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 101         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00452    |
# |    value_loss           | 151         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 34          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.005447875 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.545      |
# |    explained_variance   | 0.465       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84.1        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00464    |
# |    value_loss           | 175         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 35           |
# |    time_elapsed         | 205          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0025529577 |
# |    clip_fraction        | 0.0484       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.541       |
# |    explained_variance   | 0.553        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.9         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 102          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 36           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0024666926 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.537       |
# |    explained_variance   | 0.514        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49           |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.000154     |
# |    value_loss           | 120          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 348         |
# |    iterations           | 37          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.003553047 |
# |    clip_fraction        | 0.0183      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.3        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00196    |
# |    value_loss           | 98.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 348         |
# |    iterations           | 38          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004308606 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | 0.459       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43          |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 91.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 39          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.002601726 |
# |    clip_fraction        | 0.0427      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.523      |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36          |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00444    |
# |    value_loss           | 71.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 346          |
# |    iterations           | 40           |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0024379897 |
# |    clip_fraction        | 0.0476       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.464        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.4         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00291     |
# |    value_loss           | 85.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 41          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.003265718 |
# |    clip_fraction        | 0.0355      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.5        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0026     |
# |    value_loss           | 100         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 347          |
# |    iterations           | 42           |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0032668514 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.456       |
# |    explained_variance   | 0.35         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.9         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00236     |
# |    value_loss           | 113          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 347          |
# |    iterations           | 43           |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0037980734 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.418       |
# |    explained_variance   | 0.424        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.8         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 85.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 347          |
# |    iterations           | 44           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0051828087 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.401       |
# |    explained_variance   | 0.532        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.2         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00255     |
# |    value_loss           | 64.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 346          |
# |    iterations           | 45           |
# |    time_elapsed         | 265          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0030598256 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.399       |
# |    explained_variance   | 0.482        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.7         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000596    |
# |    value_loss           | 69.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 346          |
# |    iterations           | 46           |
# |    time_elapsed         | 272          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0059326002 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.385       |
# |    explained_variance   | 0.479        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.4         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 56           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 346          |
# |    iterations           | 47           |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0054392214 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.389       |
# |    explained_variance   | 0.431        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.5         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00595     |
# |    value_loss           | 62.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 345          |
# |    iterations           | 48           |
# |    time_elapsed         | 284          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0018809815 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.36        |
# |    explained_variance   | 0.449        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.8         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00395     |
# |    value_loss           | 67.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 49          |
# |    time_elapsed         | 290         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.002984419 |
# |    clip_fraction        | 0.0407      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.336      |
# |    explained_variance   | 0.462       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.7        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00473    |
# |    value_loss           | 55.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 50          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.002948372 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.332      |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.3        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00118    |
# |    value_loss           | 50.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 344          |
# |    iterations           | 51           |
# |    time_elapsed         | 303          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0014696654 |
# |    clip_fraction        | 0.0216       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.325       |
# |    explained_variance   | 0.398        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.8         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000825    |
# |    value_loss           | 94           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 344          |
# |    iterations           | 52           |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0028519449 |
# |    clip_fraction        | 0.0351       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.292       |
# |    explained_variance   | 0.517        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.4         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00275     |
# |    value_loss           | 55.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 343          |
# |    iterations           | 53           |
# |    time_elapsed         | 315          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0035262308 |
# |    clip_fraction        | 0.034        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.293       |
# |    explained_variance   | 0.595        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.1         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00444     |
# |    value_loss           | 41.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 343          |
# |    iterations           | 54           |
# |    time_elapsed         | 322          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0023705265 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.285       |
# |    explained_variance   | 0.457        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.7         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 60.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 342          |
# |    iterations           | 55           |
# |    time_elapsed         | 329          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0028979399 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.289       |
# |    explained_variance   | 0.472        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.1         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00422     |
# |    value_loss           | 61.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 342          |
# |    iterations           | 56           |
# |    time_elapsed         | 335          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0031877898 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.312       |
# |    explained_variance   | 0.474        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.9         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 67.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 341          |
# |    iterations           | 57           |
# |    time_elapsed         | 341          |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0024055075 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.307       |
# |    explained_variance   | 0.532        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.8         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00391     |
# |    value_loss           | 55.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 58          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.004165218 |
# |    clip_fraction        | 0.036       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.291      |
# |    explained_variance   | 0.517       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.2        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00291    |
# |    value_loss           | 55.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 341          |
# |    iterations           | 59           |
# |    time_elapsed         | 354          |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0024341627 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.29        |
# |    explained_variance   | 0.53         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.1         |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 59.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 341          |
# |    iterations           | 60           |
# |    time_elapsed         | 360          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0021709148 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.273       |
# |    explained_variance   | 0.524        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.9         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00245     |
# |    value_loss           | 67.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 340         |
# |    iterations           | 61          |
# |    time_elapsed         | 366         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.002145566 |
# |    clip_fraction        | 0.0269      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.254      |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.8        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 51.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 62           |
# |    time_elapsed         | 372          |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0054710247 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.238       |
# |    explained_variance   | 0.569        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.7         |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.00347     |
# |    value_loss           | 48           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 63           |
# |    time_elapsed         | 379          |
# |    total_timesteps      | 129024       |
# | train/                  |              |
# |    approx_kl            | 0.0021790625 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.223       |
# |    explained_variance   | 0.596        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.3         |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 47.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 64           |
# |    time_elapsed         | 385          |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# ...
# |    total_timesteps      | 210944       |
# | train/                  |              |
# |    approx_kl            | 0.0019224577 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.145       |
# |    explained_variance   | 0.695        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.5         |
# |    n_updates            | 1020         |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 56.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 104          |
# |    time_elapsed         | 643          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0012784428 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.144       |
# |    explained_variance   | 0.736        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.2         |
# |    n_updates            | 1030         |
# |    policy_gradient_loss | 0.000394     |
# |    value_loss           | 52.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 105          |
# |    time_elapsed         | 650          |
# |    total_timesteps      | 215040       |
# | train/                  |              |
# |    approx_kl            | 0.0017463013 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.157       |
# |    explained_variance   | 0.773        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.5         |
# |    n_updates            | 1040         |
# |    policy_gradient_loss | -0.000425    |
# |    value_loss           | 48.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 106          |
# |    time_elapsed         | 656          |
# |    total_timesteps      | 217088       |
# | train/                  |              |
# |    approx_kl            | 0.0032041366 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.166       |
# |    explained_variance   | 0.776        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.4         |
# |    n_updates            | 1050         |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 50.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 107          |
# |    time_elapsed         | 662          |
# |    total_timesteps      | 219136       |
# | train/                  |              |
# |    approx_kl            | 0.0036072824 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.179       |
# |    explained_variance   | 0.763        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.2         |
# |    n_updates            | 1060         |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 49.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 108          |
# |    time_elapsed         | 668          |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.0017221991 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.16        |
# |    explained_variance   | 0.672        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.6         |
# |    n_updates            | 1070         |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 86.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 109          |
# |    time_elapsed         | 675          |
# |    total_timesteps      | 223232       |
# | train/                  |              |
# |    approx_kl            | 0.0027965072 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.153       |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.4         |
# |    n_updates            | 1080         |
# |    policy_gradient_loss | -0.000432    |
# |    value_loss           | 55.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 110          |
# |    time_elapsed         | 681          |
# |    total_timesteps      | 225280       |
# | train/                  |              |
# |    approx_kl            | 0.0024263076 |
# |    clip_fraction        | 0.024        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.154       |
# |    explained_variance   | 0.78         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.8         |
# |    n_updates            | 1090         |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 48.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 111          |
# |    time_elapsed         | 687          |
# |    total_timesteps      | 227328       |
# | train/                  |              |
# |    approx_kl            | 0.0012294562 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.15        |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.9         |
# |    n_updates            | 1100         |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 42.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 112          |
# |    time_elapsed         | 692          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0014701949 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.14        |
# |    explained_variance   | 0.775        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.2         |
# |    n_updates            | 1110         |
# |    policy_gradient_loss | -0.00154     |
# |    value_loss           | 48.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 113         |
# |    time_elapsed         | 698         |
# |    total_timesteps      | 231424      |
# | train/                  |             |
# |    approx_kl            | 0.004675026 |
# |    clip_fraction        | 0.0355      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.14       |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.8        |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | -0.00138    |
# |    value_loss           | 50.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 114          |
# |    time_elapsed         | 703          |
# |    total_timesteps      | 233472       |
# | train/                  |              |
# |    approx_kl            | 0.0020855565 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.151       |
# |    explained_variance   | 0.755        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.8         |
# |    n_updates            | 1130         |
# |    policy_gradient_loss | -0.00258     |
# |    value_loss           | 57.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 115          |
# |    time_elapsed         | 709          |
# |    total_timesteps      | 235520       |
# | train/                  |              |
# |    approx_kl            | 0.0015785915 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.158       |
# |    explained_variance   | 0.787        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.6         |
# |    n_updates            | 1140         |
# |    policy_gradient_loss | -0.000433    |
# |    value_loss           | 49.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 331          |
# |    iterations           | 116          |
# |    time_elapsed         | 715          |
# |    total_timesteps      | 237568       |
# | train/                  |              |
# |    approx_kl            | 0.0024236492 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.17        |
# |    explained_variance   | 0.783        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.8         |
# |    n_updates            | 1150         |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 50.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 117         |
# |    time_elapsed         | 721         |
# |    total_timesteps      | 239616      |
# | train/                  |             |
# |    approx_kl            | 0.005562432 |
# |    clip_fraction        | 0.0325      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.174      |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.8        |
# |    n_updates            | 1160        |
# |    policy_gradient_loss | 0.00149     |
# |    value_loss           | 53.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 118          |
# |    time_elapsed         | 727          |
# |    total_timesteps      | 241664       |
# | train/                  |              |
# |    approx_kl            | 0.0022153123 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.149       |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.4         |
# |    n_updates            | 1170         |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 45           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 119          |
# |    time_elapsed         | 733          |
# |    total_timesteps      | 243712       |
# | train/                  |              |
# |    approx_kl            | 0.0032877384 |
# |    clip_fraction        | 0.0361       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.141       |
# |    explained_variance   | 0.784        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.9          |
# |    n_updates            | 1180         |
# |    policy_gradient_loss | -0.00384     |
# |    value_loss           | 43.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 120          |
# |    time_elapsed         | 739          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0017123739 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.139       |
# |    explained_variance   | 0.715        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.7         |
# |    n_updates            | 1190         |
# |    policy_gradient_loss | -0.000706    |
# |    value_loss           | 77.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 332          |
# |    iterations           | 121          |
# |    time_elapsed         | 744          |
# |    total_timesteps      | 247808       |
# | train/                  |              |
# |    approx_kl            | 0.0025495947 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.142       |
# |    explained_variance   | 0.774        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.6         |
# |    n_updates            | 1200         |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 55.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 122         |
# |    time_elapsed         | 750         |
# |    total_timesteps      | 249856      |
# | train/                  |             |
# |    approx_kl            | 0.003087407 |
# |    clip_fraction        | 0.0242      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.138      |
# |    explained_variance   | 0.79        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.9        |
# |    n_updates            | 1210        |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 48          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 123          |
# |    time_elapsed         | 756          |
# |    total_timesteps      | 251904       |
# | train/                  |              |
# |    approx_kl            | 0.0018045818 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.132       |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.8         |
# |    n_updates            | 1220         |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 71           |
# ------------------------------------------

# %%
env = CustomTradingEnv(df=df, window_size=20, frame_bound=(1000, 1250))
obs, _ = env.reset()

while True:
    action, _states = model.predict(obs)
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    # env.render()
    if done:
        print("info:", info)
        break
# Out:
# info: {'total_reward': 292.170012, 'total_profit': 2.4188781234812984, 'position': <Positions.Long: 1>}

# %%
plt.figure(figsize=(20, 9))
plt.cla()
env.render_all()
plt.show()
